# %% [markdown]
# ##### News Sentiment Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys

# %%
working_dir = os.getcwd()

# %%
# sys.path.append(os.path.abspath(os.path.join(working_dir, "..")))
sys.path.append(os.path.abspath('../dataset'))
sys.path.append(os.path.abspath('../scripts'))

# %%
from load_data import data_loader

# %%
df = data_loader('../dataset/raw_analyst_ratings.csv')

# %%
df
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407328 entries, 0 to 1407327
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1407328 non-null  int64
#  1   headline    1407328 non-null  object
#  2   url         1407328 non-null  object
#  3   publisher   1407328 non-null  object
#  4   date        1407328 non-null  object
#  5   stock       1407328 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 64.4+ MB

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# headline      object
# url           object
# publisher     object
# date          object
# stock         object
# dtype: object

# %%
df =df.drop('Unnamed: 0', axis =1)

# %%
df['date'] = pd.to_datetime(df['date'], format='ISO8601')
df.set_index('date',inplace=True)

# %%
df
# Out:
#                                                                     headline  \
# date
# 2020-06-05 10:30:54-04:00            Stocks That Hit 52-Week Highs On Friday
# 2020-06-03 10:45:20-04:00         Stocks That Hit 52-Week Highs On Wednesday
# 2020-05-26 04:30:07-04:00                      71 Biggest Movers From Friday
# 2020-05-22 12:45:06-04:00       46 Stocks Moving In Friday's Mid-Day Session
# 2020-05-22 11:38:59-04:00  B of A Securities Maintains Neutral on Agilent...
# ...                                                                      ...
# 2011-08-29 00:00:00-04:00             Top Narrow Based Indexes For August 29
# 2011-06-22 00:00:00-04:00  Recap: Wednesday's Top Percentage Gainers and ...
# 2011-06-21 00:00:00-04:00  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 2011-06-21 00:00:00-04:00  Oppenheimer Initiates China Zenix At Outperfor...
# 2011-05-12 00:00:00-04:00  China Zenix Auto International Opens For Tradi...
#
# ...

# %%
df.isnull().sum()
# Out:
# headline     0
# url          0
# publisher    0
# stock        0
# dtype: int64

# %%
publisher_counts = df['publisher'].value_counts()
print(publisher_counts)
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
#                       ...
# MoneyGeek                 1
# muathe                    1
# Robert Morris             1
# LeftCoastHedgie           1
# Jeremie Capron            1
# Name: count, Length: 1034, dtype: int64

# %%
daily_counts = df.resample('D').size()

# %%
daily_counts.plot(figsize=(12, 6))
plt.title('Daily News Frequency')
plt.xlabel('Date')
plt.ylabel('Number of News Articles')
plt.show()

# %%
# 2. Weekly News Frequency:
weekly_counts = df.resample('W').size() #Count of news items per week
weekly_counts.plot(figsize=(12,6))
plt.title('Weekly News Frequency')
plt.xlabel('Week')
plt.ylabel('Number of News Articles')
plt.show()


# 3. Monthly News Frequency:
monthly_counts = df.resample('M').size()  #Count of news items per month
monthly_counts.plot(figsize=(12,6))
plt.title('Monthly News Frequency')
plt.xlabel('Month')
plt.ylabel('Number of News Articles')
plt.show()
# Out:
# C:\Users\Abreham\AppData\Local\Temp\ipykernel_5108\1273869647.py:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_counts = df.resample('M').size()  #Count of news items per month
